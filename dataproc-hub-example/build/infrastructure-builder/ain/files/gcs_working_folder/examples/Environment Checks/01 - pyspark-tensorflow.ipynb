# %%
from pyspark import SparkContext
from pyspark import SparkConf

# %%
sc.version
# Out:
# '2.4.4'

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.1.0'

# %%
sc.parallelize(range(0,20)).count()
# Out:
# 20

# %%
# !conda list
# Out:
# # packages in environment at /opt/conda/anaconda:
# #
# # Name                    Version                   Build  Channel
# _ipyw_jlab_nb_ext_conf    0.1.0                    py36_0
# _libgcc_mutex             0.1                        main
# absl-py                   0.9.0                     <pip>
# alabaster                 0.7.12                     py_0
# alembic                   1.3.1                      py_0
# anaconda                  5.2.0                    py36_3
# anaconda-client           1.7.2                    py36_0
# anaconda-navigator        1.8.7                    py36_0
# anaconda-project          0.8.4                      py_0
# ansiwrap                  0.8.4                     <pip>
# appdirs                   1.4.3                     <pip>
# argparse                  1.4.0                     <pip>
# arrow                     0.15.5                    <pip>
# arrow-cpp                 0.15.1           py36h7cd5009_5
# asn1crypto                1.3.0                    py36_0    main
# astor                     0.8.1                     <pip>
# astroid                   2.3.3                    py36_0
# astropy                   4.0              py36h7b6447c_0
# async_generator           1.10                       py_0
# atomicwrites              1.3.0                    py36_1
# attr                      0.3.1                     <pip>
# attrs                     19.3.0                     py_0    main
# babel                     2.8.0                      py_0
# backcall                  0.1.0                    py36_0    main
# backports                 1.0                        py_2
# backports.functools_lru_cache 1.6.1                      py_0
# backports.shutil_get_terminal_size 1.0.0                    py36_2
# backports.tempfile        1.0                        py_1
# backports.weakref         1.0.post1                  py_1
# bcolz                     1.2.1                     <pip>
# beautifulsoup4            4.8.2                    py36_0
# binaryornot               0.4.4                     <pip>
# bitarray                  1.2.1            py36h7b6447c_0
# bkcharts                  0.2                      py36_0
# black                     19.10b0                   <pip>
# blas                      1.0                         mkl
# blaze                     0.11.3                   py36_0
# bleach                    3.1.0                      py_0    main
# blinker                   1.4                      py36_0
# blosc                     1.16.3               hd408876_0
# bokeh                     1.4.0                    py36_0
# boost-cpp                 1.71.0               h7b6447c_0
# boto                      2.49.0                   py36_0
# bottleneck                1.3.2            py36heb32a55_0
# brotli                    1.0.7                he6710b0_0
# bzip2                     1.0.8                h7b6447c_0
# c-ares                    1.15.0            h7b6447c_1001
# ca-certificates           2020.1.1                      0    main
# cachetools                4.0.0                     <pip>
# cairo                     1.14.12              h8948797_3
# certifi                   2019.11.28               py36_0    main
# certipy                   0.1.3                      py_0
# cffi                      1.14.0           py36h2e261b9_0    main
# chardet                   3.0.4                 py36_1003    main
# click                     7.0                        py_0
# cloudpickle               1.3.0                      py_0
# clyent                    1.2.2                    py36_1
# colorama                  0.4.3                      py_0    main
# conda                     4.5.13                   py36_0
# conda-build               3.18.11                  py36_0
# conda-env                 2.6.0                         1
# conda-package-handling    1.6.0            py36h7b6447c_0
# conda-verify              3.4.2                      py_1
# configparser              4.0.2                     <pip>
# configurable-http-proxy   4.2.0           node10_h1f298a6_2    conda-forge
# confuse                   1.0.0                     <pip>
# contextlib2               0.6.0.post1                py_0
# cookiecutter              1.7.0                     <pip>
# cryptography              2.8              py36h1ba5d50_0    main
# curl                      7.60.0               h84994c4_0
# cycler                    0.10.0                   py36_0
# cython                    0.29.15          py36he6710b0_0
# cytoolz                   0.10.1           py36h7b6447c_0
# dask                      2.11.0                     py_0
# dask-core                 2.11.0                     py_0
# datalab                   1.1.5                     <pip>
# datashape                 0.5.4                    py36_1
# dbus                      1.13.12              h746ee38_0
# decorator                 4.4.1                      py_0    main
# defusedxml                0.6.0                      py_0    main
# distlib                   0.3.0                     <pip>
# distributed               2.11.0                   py36_0
# docker                    4.2.0                     <pip>
# docutils                  0.16                     py36_0
# double-conversion         3.1.5                he6710b0_1
# entrypoints               0.3                      py36_0    main
# enum34                    1.1.9                     <pip>
# et_xmlfile                1.0.1                    py36_0
# expat                     2.2.6                he6710b0_0
# fairing                   0.5.3                     <pip>
# fastcache                 1.1.0            py36h7b6447c_0
# filelock                  3.0.12                     py_0
# findspark                 1.3.0                      py_1    conda-forge
# flask                     1.1.1                      py_0
# flask-cors                3.0.8                      py_0
# fontconfig                2.13.0               h9420a91_0
# freetype                  2.9.1                h8a8886c_1
# fribidi                   1.0.5                h7b6447c_0
# fsspec                    0.6.2                      py_0
# future                    0.18.2                   py36_0
# gast                      0.2.2                     <pip>
# gcsfs                     0.6.0                     <pip>
# get_terminal_size         1.0.0                haa9412d_0
# gevent                    1.4.0            py36h7b6447c_0
# gflags                    2.2.2                he6710b0_0
# gitdb2                    2.0.6                      py_0    main
# gitpython                 3.0.5                      py_0    main
# glib                      2.63.1               h5a9c865_0
# glob2                     0.7                        py_0
# glog                      0.4.0                he6710b0_0
# gmp                       6.1.2                h6c8ec71_1    main
# gmpy2                     2.0.8            py36h10f8cd9_2
# google-api-core           1.16.0                    <pip>
# google-api-python-client  1.7.11                    <pip>
# google-auth               1.11.2                    <pip>
# google-auth-httplib2      0.0.3                     <pip>
# google-auth-oauthlib      0.4.1                     <pip>
# google-cloud              0.34.0                    <pip>
# google-cloud-bigquery     1.24.0                    <pip>
# google-cloud-core         1.3.0                     <pip>
# google-cloud-dataproc     0.6.1                     <pip>
# google-cloud-datastore    1.11.0                    <pip>
# google-cloud-language     1.3.0                     <pip>
# google-cloud-logging      1.15.0                    <pip>
# google-cloud-monitoring   0.31.1                    <pip>
# google-cloud-spanner      1.14.0                    <pip>
# google-cloud-storage      1.10.0                    <pip>
# google-cloud-translate    2.0.1                     <pip>
# google-pasta              0.1.8                     <pip>
# google-resumable-media    0.5.0                     <pip>
# googleapis-common-protos  1.51.0                    <pip>
# graphite2                 1.3.13               h23475e2_0
# greenlet                  0.4.15           py36h7b6447c_0
# grpc-cpp                  1.26.0               hf8bcb03_0
# grpc-google-iam-v1        0.12.3                    <pip>
# grpcio                    1.27.2                    <pip>
# gst-plugins-base          1.14.0               hbbd80ab_1
# gstreamer                 1.14.0               hb453b48_1
# h5py                      2.10.0           py36h7918eee_0
# harfbuzz                  1.8.8                hffaf4a1_0
# hdf5                      1.10.4               hb1b8bf9_0
# heapdict                  1.0.1                      py_0
# html5lib                  1.0.1                      py_0
# htmlmin                   0.1.12                    <pip>
# httplib2                  0.17.0                    <pip>
# hypothesis                5.5.4                      py_0
# icu                       58.2                 h9c2bf20_1
# idna                      2.8                      py36_0    main
# imageio                   2.6.1                    py36_0
# imagesize                 1.2.0                      py_0
# importlib-resources       1.2.0                     <pip>
# importlib_metadata        1.5.0                    py36_0    main
# intel-openmp              2020.0                      166
# ipykernel                 5.1.4            py36h39e3cac_0    main
# ipyparallel               6.2.4                    py36_0
# ipython                   7.12.0           py36h5ca1d4c_0    main
# ipython-sql               0.3.9                     <pip>
# ipython_genutils          0.2.0                    py36_0    main
# ipywidgets                7.5.1                      py_0    main
# isort                     4.3.21                   py36_0
# itsdangerous              1.1.0                      py_0
# jbig                      2.1                  hdba287a_0
# jdcal                     1.4.1                      py_0
# jedi                      0.16.0                   py36_0    main
# jgscm                     0.1.9                     <pip>
# jinja2                    2.11.1                     py_0    main
# jinja2-time               0.2.0                     <pip>
# joblib                    0.14.1                     py_0
# jpeg                      9b                   h024ee3a_2
# json5                     0.9.1                      py_0    main
# jsonschema                3.2.0                    py36_0    main
# jupyter                   1.0.0                    py36_4
# jupyter-contrib-core      0.3.3                     <pip>
# jupyter-contrib-nbextensions 0.5.1                     <pip>
# jupyter-highlight-selected-word 0.2.0                     <pip>
# jupyter-http-over-ws      0.0.7                     <pip>
# jupyter-latex-envs        1.4.6                     <pip>
# jupyter-nbextensions-configurator 0.4.1                     <pip>
# jupyter_client            5.3.4                    py36_0    main
# jupyter_console           5.2.0            py36he59e554_1
# jupyter_core              4.6.1                    py36_0    main
# jupyterhub                1.0.0                    py36_0
# jupyterlab                1.2.6              pyhf63ae98_0    main
# jupyterlab-gcloud-auth    0.2.4                     <pip>
# jupyterlab-git            0.9.0                      py_0    conda-forge
# jupyterlab_launcher       0.13.1                   py36_0
# jupyterlab_server         1.0.6                      py_0    main
# kaggle                    1.5.6                     <pip>
# Keras-Applications        1.0.8                     <pip>
# Keras-Preprocessing       1.1.0                     <pip>
# kiwisolver                1.1.0            py36he6710b0_0
# krb5                      1.17.1               h173b8e3_0
# kubernetes                10.0.1                    <pip>
# lazy-object-proxy         1.4.3            py36h7b6447c_0
# ld_impl_linux-64          2.33.1               h53a641e_7
# libarchive                3.3.3                h5d8350f_5
# libboost                  1.71.0               h97c9712_0
# libcurl                   7.68.0               h20c2e04_0
# libedit                   3.1.20181209         hc058e9b_0
# libevent                  2.1.8                h1ba5d50_0
# libffi                    3.2.1                hd88cf55_4    main
# libgcc                    7.2.0                h69d50b8_2
# libgcc-ng                 9.1.0                hdf63c60_0
# libgfortran-ng            7.3.0                hdf63c60_0
# liblief                   0.9.0                h7725739_2
# libpng                    1.6.37               hbc83047_0
# libprotobuf               3.11.2               hd408876_0
# libsodium                 1.0.16               h1bed415_0
# libssh2                   1.8.2                h1ba5d50_0
# libstdcxx-ng              9.1.0                hdf63c60_0
# libtiff                   4.1.0                h2733197_0
# libtool                   2.4.6                h7b6447c_5
# libuuid                   1.0.3                h1bed415_2
# libxcb                    1.13                 h1bed415_1
# libxml2                   2.9.9                hea5a465_1
# libxslt                   1.1.33               h7d1a2b0_0
# llvmlite                  0.31.0           py36hd408876_0
# locket                    0.2.0                    py36_1
# lxml                      4.5.0            py36hefd8a0e_0
# lz4-c                     1.8.1.2              h14c3975_0
# lzo                       2.10                 h49e0be7_2
# mako                      1.1.1                      py_0
# Markdown                  3.2.1                     <pip>
# markupsafe                1.1.1            py36h7b6447c_0    main
# matplotlib                2.2.2            py36h0e671d2_1
# matplotlib                3.1.3                     <pip>
# mccabe                    0.6.1                    py36_1
# metakernel                0.24.3                     py_0
# missingno                 0.4.2                     <pip>
# mistune                   0.8.4            py36h7b6447c_0    main
# mkl                       2020.0                      166
# mkl-service               2.3.0            py36he904b0f_0
# mkl_fft                   1.0.15           py36ha843d7b_0
# mkl_random                1.1.0            py36hd6b4f25_0
# mock                      4.0.1                      py_0
# more-itertools            8.2.0                      py_0
# mpc                       1.1.0                h10f8cd9_1
# mpfr                      4.0.1                hdf1c602_3
# mpmath                    1.1.0                    py36_0
# msgpack-python            0.6.1            py36hfd86e86_1
# multipledispatch          0.6.0                    py36_0
# navigator-updater         0.2.1                    py36_0
# nb_conda                  2.2.1                    py36_0    main
# nb_conda_kernels          2.2.2                    py36_0    main
# nbclient                  0.1.0                     <pip>
# nbconvert                 5.6.1                    py36_0    main
# nbdime                    1.1.0                    py36_0    conda-forge
# nbformat                  5.0.4                      py_0    main
# nbpresent                 3.0.2                    py36_1    main
# ncurses                   6.2                  he6710b0_0
# networkx                  2.4                        py_0
# nltk                      3.4.5                    py36_0
# nodejs                    10.13.0              he6710b0_0    main
# nose                      1.3.7                    py36_2
# notebook                  6.0.3                    py36_0    main
# numba                     0.48.0           py36h0573a6f_0
# numexpr                   2.7.1            py36h423224d_0
# numpy                     1.18.1           py36h4f9e942_0
# numpy-base                1.18.1           py36hde5b4d6_1
# numpydoc                  0.9.2                      py_0
# oauth2client              4.1.3                     <pip>
# oauthlib                  3.1.0                      py_0
# odo                       0.5.1                    py36_0
# olefile                   0.46                       py_0
# opencv-python             4.2.0.32                  <pip>
# openpyxl                  3.0.3                      py_0
# openssl                   1.1.1d               h7b6447c_4    main
# opt-einsum                3.2.0                     <pip>
# packaging                 20.1                       py_0
# pamela                    1.0.0                      py_0
# pandas                    1.0.1            py36h0573a6f_0
# pandas-profiling          2.5.0                     <pip>
# pandoc                    2.2.3.2                       0    main
# pandocfilters             1.4.2                    py36_1    main
# pango                     1.42.4               h049681c_0
# papermill                 2.0.0                     <pip>
# parso                     0.6.1                      py_0    main
# partd                     1.1.0                      py_0
# patchelf                  0.10                 he6710b0_0
# path                      13.1.0                   py36_0
# path.py                   12.4.0                        0
# pathlib2                  2.3.5                    py36_0
# pathspec                  0.7.0                     <pip>
# patsy                     0.5.1                    py36_0
# pcre                      8.43                 he6710b0_0
# pep8                      1.7.1                    py36_0
# pexpect                   4.8.0                    py36_0    main
# phik                      0.9.9                     <pip>
# pickleshare               0.7.5                    py36_0    main
# pillow                    7.0.0            py36hb39fc2d_0
# Pillow-SIMD               7.0.0.post3               <pip>
# pip                       20.0.2                   py36_1    main
# pixman                    0.38.0               h7b6447c_0
# pkginfo                   1.5.0.1                  py36_0
# plotly                    4.5.2                     <pip>
# pluggy                    0.13.1                   py36_0
# ply                       3.11                     py36_0
# portalocker               1.5.2                    py36_0
# poyo                      0.5.0                     <pip>
# prettytable               0.7.2                     <pip>
# prometheus_client         0.7.1                      py_0    main
# prompt_toolkit            3.0.3                      py_0    main
# protobuf                  3.11.3                    <pip>
# psutil                    5.6.7            py36h7b6447c_0
# ptyprocess                0.6.0                    py36_0    main
# py                        1.8.1                      py_0
# py-lief                   0.9.0            py36h7725739_2
# py4j                      0.10.7                    <pip>
# pyarrow                   0.16.0                    <pip>
# pyarrow                   0.15.1           py36h0573a6f_0
# pyasn1                    0.4.8                     <pip>
# pyasn1-modules            0.2.8                     <pip>
# pycodestyle               2.5.0                    py36_0
# pycosat                   0.6.3            py36h7b6447c_0
# pycparser                 2.19                       py_0    main
# pycrypto                  2.6.1            py36h14c3975_9
# pycurl                    7.43.0.5         py36h1ba5d50_0
# pydot                     1.4.1                     <pip>
# pyflakes                  2.1.1                    py36_0
# pygments                  2.5.2                      py_0    main
# pyjwt                     1.7.1                    py36_0
# pylint                    2.4.4                    py36_0
# pyodbc                    4.0.30           py36he6710b0_0
# pyopenssl                 19.1.0                   py36_0    main
# pyparsing                 2.4.6                      py_0
# pyqt                      5.9.2            py36h751905a_0
# pyrsistent                0.15.7           py36h7b6447c_0    main
# pysocks                   1.7.1                    py36_0    main
# pyspark                   2.4.4                     <pip>
# pytables                  3.6.1            py36h71ec239_0
# pytest                    5.0.1                    py36_0
# pytest-arraydiff          0.3              py36h39e3cac_0
# pytest-astropy            0.8.0                      py_0
# pytest-astropy-header     0.1.2                      py_0
# pytest-doctestplus        0.5.0                      py_0
# pytest-openfiles          0.4.0                      py_0
# pytest-pylint             0.15.0                    <pip>
# pytest-remotedata         0.3.2                    py36_0
# python                    3.6.10               h0371630_0    main
# python-dateutil           2.8.1                      py_0    main
# python-editor             1.0.4                      py_0
# python-libarchive-c       2.8                     py36_13
# python-slugify            4.0.0                     <pip>
# pytz                      2019.3                     py_0
# pywavelets                1.1.1            py36h7b6447c_0
# pyyaml                    5.3              py36h7b6447c_0
# pyzmq                     18.1.1           py36he6710b0_0    main
# qt                        5.9.5                h7e424d6_0
# qtawesome                 0.6.1                      py_0
# qtconsole                 4.3.1            py36h8f73b5b_0
# qtpy                      1.9.0                      py_0
# re2                       2019.08.01           he6710b0_0
# readline                  7.0                  h7b6447c_5
# regex                     2020.2.20                 <pip>
# requests                  2.22.0                   py36_1    main
# requests-oauthlib         1.3.0                     <pip>
# retrying                  1.3.3                     <pip>
# ripgrep                   11.0.2               he32d670_0
# rope                      0.16.0                     py_0
# rsa                       4.0                       <pip>
# ruamel_yaml               0.15.87          py36h7b6447c_0
# scikit-image              0.13.1           py36h14c3975_1
# scikit-learn              0.22.1           py36hd81dba3_0
# scipy                     1.4.1            py36h0b6359f_0
# seaborn                   0.8.1            py36hfad7ec4_0
# send2trash                1.5.0                    py36_0    main
# setuptools                45.2.0                   py36_0    main
# simplegeneric             0.8.1                    py36_2
# singledispatch            3.4.0.3                  py36_0
# sip                       4.19.13          py36he6710b0_0
# six                       1.14.0                   py36_0    main
# smmap2                    2.0.5                      py_0    main
# snappy                    1.1.7                hbae5bb6_3
# snowballstemmer           2.0.0                      py_0
# sortedcollections         1.1.2                    py36_0
# sortedcontainers          2.1.0                    py36_0
# soupsieve                 1.9.5                    py36_0
# sphinx                    2.4.0                      py_0
# sphinxcontrib             1.0                      py36_1
# sphinxcontrib-applehelp   1.0.1                      py_0
# sphinxcontrib-devhelp     1.0.1                      py_0
# sphinxcontrib-htmlhelp    1.0.2                      py_0
# sphinxcontrib-jsmath      1.0.1                      py_0
# sphinxcontrib-qthelp      1.0.2                      py_0
# sphinxcontrib-serializinghtml 1.1.3                      py_0
# sphinxcontrib-websupport  1.2.0                      py_0
# spyder                    3.2.8                    py36_0
# spylon                    0.3.0                      py_1    conda-forge
# spylon-kernel             0.4.1                   py_1000    conda-forge
# sqlalchemy                1.3.13           py36h7b6447c_0
# sqlite                    3.31.1               h7b6447c_0
# sqlparse                  0.3.1                     <pip>
# statsmodels               0.11.0           py36h7b6447c_0
# sympy                     1.5.1                    py36_0
# tangled-up-in-unicode     0.0.3                     <pip>
# tbb                       2020.0               hfd86e86_0
# tbb4py                    2020.0           py36hfd86e86_0
# tblib                     1.6.0                      py_0
# tenacity                  6.1.0                     <pip>
# tensorboard               2.1.0                     <pip>
# tensorflow                2.1.0                     <pip>
# tensorflow-estimator      2.1.0                     <pip>
# termcolor                 1.1.0                     <pip>
# terminado                 0.8.3                    py36_0    main
# testpath                  0.4.4                      py_0    main
# text-unidecode            1.3                       <pip>
# textwrap3                 0.9.2                     <pip>
# thrift-cpp                0.11.0               h02b749d_3
# tk                        8.6.8                hbc83047_0
# toml                      0.10.0                    <pip>
# toolz                     0.10.0                     py_0
# tornado                   5.1.1                     <pip>
# tornado                   5.0.2            py36h14c3975_0    main
# tqdm                      4.42.1                     py_0    main
# tqdm                      4.42.0                    <pip>
# traitlets                 4.3.3                    py36_0    main
# typed-ast                 1.4.1            py36h7b6447c_0
# typing                    3.6.4                    py36_0
# unicodecsv                0.14.1                   py36_0
# unixodbc                  2.3.7                h14c3975_0
# uriparser                 0.9.3                he6710b0_1
# uritemplate               3.0.1                     <pip>
# urllib3                   1.25.8                   py36_0    main
# virtualenv                20.0.7                    <pip>
# visions                   0.2.2                     <pip>
# wcwidth                   0.1.8                      py_0    main
# webencodings              0.5.1                    py36_1    main
# websocket-client          0.57.0                    <pip>
# werkzeug                  1.0.0                      py_0
# wheel                     0.34.2                   py36_0    main
# whichcraft                0.6.1                     <pip>
# widgetsnbextension        3.5.1                    py36_0
# wrapt                     1.11.2           py36h7b6447c_0
# xlrd                      1.2.0                      py_0
# xlsxwriter                1.2.7                      py_0
# xlwt                      1.3.0                    py36_0
# xz                        5.2.4                h14c3975_4
# yaml                      0.1.7                had09818_2
# zeromq                    4.3.1                he6710b0_3
# zict                      1.0.0                      py_0
# zipp                      2.2.0                      py_0    main
# zlib                      1.2.11               h7b6447c_3
# zstd                      1.3.7                h0b5b093_0

# %%
# !ls /usr/lib/spark/jars/
# Out:
# accessors-smart-1.2.jar
# activation-1.1.1.jar
# aircompressor-0.10.jar
# all-1.1.2.pom
# antlr-2.7.7.jar
# antlr4-runtime-4.7.jar
# antlr-runtime-3.4.jar
# aopalliance-1.0.jar
# aopalliance-repackaged-2.4.0-b34.jar
# apacheds-i18n-2.0.0-M15.jar
# apacheds-kerberos-codec-2.0.0-M15.jar
# apache-log4j-extras-1.2.17.jar
# api-asn1-api-1.0.0-M20.jar
# api-util-1.0.0-M20.jar
# arpack_combined_all-0.1.jar
# arrow-format-0.10.0.jar
# arrow-memory-0.10.0.jar
# arrow-vector-0.10.0.jar
# audience-annotations-0.5.0.jar
# automaton-1.11-8.jar
# avro-1.8.2.jar
# avro-ipc-1.8.2.jar
# avro-mapred-1.8.2-hadoop2.jar
# aws-java-sdk-bundle-1.11.199.jar
# azure-keyvault-core-0.8.0.jar
# azure-storage-5.4.0.jar
# bonecp-0.8.0.RELEASE.jar
# breeze_2.11-0.13.2.jar
# breeze-macros_2.11-0.13.2.jar
# calcite-avatica-1.2.0-incubating.jar
# calcite-core-1.2.0-incubating.jar
# calcite-linq4j-1.2.0-incubating.jar
# chill_2.11-0.9.3.jar
# chill-java-0.9.3.jar
# commons-beanutils-1.9.3.jar
# commons-cli-1.2.jar
# commons-codec-1.10.jar
# commons-collections-3.2.2.jar
# commons-compiler-3.0.9.jar
# commons-compress-1.8.1.jar
# commons-configuration-1.6.jar
# commons-crypto-1.0.0.jar
# commons-dbcp-1.4.jar
# commons-digester-1.8.jar
# commons-httpclient-3.1.jar
# commons-io-2.4.jar
# commons-lang-2.6.jar
# commons-lang3-3.5.jar
# commons-logging-1.1.3.jar
# commons-math3-3.4.1.jar
# commons-net-3.1.jar
# commons-pool-1.5.4.jar
# compress-lzf-1.0.3.jar
# core-1.1.2.jar
# curator-client-2.6.0.jar
# curator-framework-2.6.0.jar
# curator-recipes-2.6.0.jar
# datanucleus-api-jdo-3.2.6.jar
# datanucleus-core-3.2.10.jar
# datanucleus-rdbms-3.2.9.jar
# derby-10.12.1.1.jar
# ehcache-3.3.1.jar
# eigenbase-properties-1.1.5.jar
# flatbuffers-1.2.0-3f79e055.jar
# generex-1.0.2.jar
# geronimo-jcache_1.0_spec-1.0-alpha-1.jar
# gson-2.2.4.jar
# guava-14.0.1.jar
# guice-3.0.jar
# guice-servlet-3.0.jar
# hadoop-annotations-2.9.2.jar
# hadoop-auth-2.9.2.jar
# hadoop-aws-2.9.2.jar
# hadoop-azure-2.9.2.jar
# hadoop-client-2.9.2.jar
# hadoop-common-2.9.2.jar
# hadoop-hdfs-client-2.9.2.jar
# hadoop-mapreduce-client-app-2.9.2.jar
# hadoop-mapreduce-client-common-2.9.2.jar
# hadoop-mapreduce-client-core-2.9.2.jar
# hadoop-mapreduce-client-jobclient-2.9.2.jar
# hadoop-mapreduce-client-shuffle-2.9.2.jar
# hadoop-yarn-api-2.9.2.jar
# hadoop-yarn-client-2.9.2.jar
# hadoop-yarn-common-2.9.2.jar
# hadoop-yarn-registry-2.9.2.jar
# hadoop-yarn-server-common-2.9.2.jar
# hadoop-yarn-server-web-proxy-2.9.2.jar
# HikariCP-java7-2.4.12.jar
# hive-beeline-1.2.1.spark2.jar
# hive-cli-1.2.1.spark2.jar
# hive-exec-1.2.1.spark2.jar
# hive-jdbc-1.2.1.spark2.jar
# hive-metastore-1.2.1.spark2.jar
# hk2-api-2.4.0-b34.jar
# hk2-locator-2.4.0-b34.jar
# hk2-utils-2.4.0-b34.jar
# hppc-0.7.2.jar
# htrace-core4-4.1.0-incubating.jar
# httpclient-4.5.6.jar
# httpcore-4.4.10.jar
# ivy-2.4.0.jar
# jackson-annotations-2.6.7.jar
# jackson-core-2.6.7.jar
# jackson-core-asl-1.9.13.jar
# jackson-databind-2.6.7.1.jar
# jackson-dataformat-yaml-2.6.7.jar
# jackson-jaxrs-1.9.13.jar
# jackson-mapper-asl-1.9.13.jar
# jackson-module-jaxb-annotations-2.6.7.jar
# jackson-module-paranamer-2.7.9.jar
# jackson-module-scala_2.11-2.6.7.1.jar
# jackson-xc-1.9.13.jar
# janino-3.0.9.jar
# JavaEWAH-0.3.2.jar
# javassist-3.18.1-GA.jar
# javax.annotation-api-1.2.jar
# javax.el-3.0.1-b11.jar
# javax.inject-1.jar
# javax.inject-2.4.0-b34.jar
# javax.servlet-api-3.1.0.jar
# javax.ws.rs-api-2.0.1.jar
# javolution-5.5.1.jar
# jaxb-api-2.2.2.jar
# jcip-annotations-1.0-1.jar
# jcl-over-slf4j-1.7.16.jar
# jdo-api-3.0.1.jar
# jersey-client-2.22.2.jar
# jersey-common-2.22.2.jar
# jersey-container-servlet-2.22.2.jar
# jersey-container-servlet-core-2.22.2.jar
# jersey-guava-2.22.2.jar
# jersey-media-jaxb-2.22.2.jar
# jersey-server-2.22.2.jar
# jetty-6.1.26.jar
# jetty-sslengine-6.1.26.jar
# jetty-util-6.1.26.jar
# jline-2.14.6.jar
# jniloader-1.1.jar
# joda-time-2.9.3.jar
# jodd-core-3.5.2.jar
# jpam-1.1.jar
# json4s-ast_2.11-3.5.3.jar
# json4s-core_2.11-3.5.3.jar
# json4s-jackson_2.11-3.5.3.jar
# json4s-scalap_2.11-3.5.3.jar
# json-smart-2.3.jar
# jsp-api-2.1.jar
# jsr305-1.3.9.jar
# jta-1.1.jar
# jtransforms-2.4.0.jar
# jul-to-slf4j-1.7.16.jar
# kryo-shaded-4.0.2.jar
# kubernetes-client-4.4.2.jar
# kubernetes-model-4.4.2.jar
# kubernetes-model-common-4.4.2.jar
# leveldbjni-all-1.8.jar
# libfb303-0.9.3.jar
# libthrift-0.9.3.jar
# log4j-1.2.17.jar
# logging-interceptor-3.12.0.jar
# lz4-java-1.4.0.jar
# machinist_2.11-0.6.1.jar
# macro-compat_2.11-1.1.1.jar
# metrics-core-3.1.5.jar
# metrics-graphite-3.1.5.jar
# metrics-json-3.1.5.jar
# metrics-jvm-3.1.5.jar
# minlog-1.3.0.jar
# mssql-jdbc-6.2.1.jre7.jar
# native_ref-java-1.1.jar
# native_system-java-1.1.jar
# netlib-native_ref-linux-armhf-1.1-natives.jar
# netlib-native_ref-linux-i686-1.1-natives.jar
# netlib-native_ref-linux-x86_64-1.1-natives.jar
# netlib-native_ref-osx-x86_64-1.1-natives.jar
# netlib-native_ref-win-i686-1.1-natives.jar
# netlib-native_ref-win-x86_64-1.1-natives.jar
# netlib-native_system-linux-armhf-1.1-natives.jar
# netlib-native_system-linux-i686-1.1-natives.jar
# netlib-native_system-linux-x86_64-1.1-natives.jar
# netlib-native_system-osx-x86_64-1.1-natives.jar
# netlib-native_system-win-i686-1.1-natives.jar
# netlib-native_system-win-x86_64-1.1-natives.jar
# netty-3.9.9.Final.jar
# netty-all-4.1.17.Final.jar
# nimbus-jose-jwt-4.41.1.jar
# objenesis-2.5.1.jar
# okhttp-2.7.5.jar
# okhttp-3.8.1.jar
# okio-1.13.0.jar
# opencsv-2.3.jar
# orc-core-1.5.5-nohive.jar
# orc-mapreduce-1.5.5-nohive.jar
# orc-shims-1.5.5.jar
# oro-2.0.8.jar
# osgi-resource-locator-1.0.1.jar
# paranamer-2.8.jar
# parquet-column-1.10.1.jar
# parquet-common-1.10.1.jar
# parquet-encoding-1.10.1.jar
# parquet-format-2.4.0.jar
# parquet-hadoop-1.10.1.jar
# parquet-hadoop-bundle-1.6.0.jar
# parquet-jackson-1.10.1.jar
# protobuf-java-2.5.0.jar
# py4j-0.10.7.jar
# pyrolite-4.13.jar
# RoaringBitmap-0.7.45.jar
# scala-compiler-2.11.12.jar
# scala-library-2.11.12.jar
# scala-parser-combinators_2.11-1.1.0.jar
# scala-reflect-2.11.12.jar
# scala-xml_2.11-1.0.5.jar
# shapeless_2.11-2.3.2.jar
# shims-0.7.45.jar
# slf4j-api-1.7.16.jar
# slf4j-log4j12-1.7.16.jar
# snakeyaml-1.15.jar
# snappy-0.2.jar
# snappy-java-1.1.7.3.jar
# spark-bigquery-latest.jar
# spark-catalyst_2.11-2.4.4.jar
# spark-core_2.11-2.4.4.jar
# spark-external-shuffle-20190311-rc1.jar
# spark-graphx_2.11-2.4.4.jar
# spark-hive_2.11-2.4.4.jar
# spark-hive-thriftserver_2.11-2.4.4.jar
# spark-kubernetes_2.11-2.4.4.jar
# spark-kvstore_2.11-2.4.4.jar
# spark-launcher_2.11-2.4.4.jar
# spark-mllib_2.11-2.4.4.jar
# spark-mllib-local_2.11-2.4.4.jar
# spark-network-common_2.11-2.4.4.jar
# spark-network-shuffle_2.11-2.4.4.jar
# spark-repl_2.11-2.4.4.jar
# spark-sketch_2.11-2.4.4.jar
# spark-sql_2.11-2.4.4.jar
# spark-streaming_2.11-2.4.4.jar
# spark-tags_2.11-2.4.4.jar
# spark-tags_2.11-2.4.4-tests.jar
# spark-unsafe_2.11-2.4.4.jar
# spark-yarn_2.11-2.4.4.jar
# spire_2.11-0.13.0.jar
# spire-macros_2.11-0.13.0.jar
# ST4-4.0.4.jar
# stax2-api-3.1.4.jar
# stax-api-1.0.1.jar
# stax-api-1.0-2.jar
# stream-2.7.0.jar
# stringtemplate-3.2.1.jar
# super-csv-2.2.0.jar
# univocity-parsers-2.7.3.jar
# validation-api-1.1.0.Final.jar
# woodstox-core-5.0.3.jar
# xbean-asm6-shaded-4.8.jar
# xmlenc-0.52.jar
# xz-1.5.jar
# zjsonpatch-0.3.0.jar
# zookeeper-3.4.13.jar
# zstd-jni-1.3.2-2.jar
